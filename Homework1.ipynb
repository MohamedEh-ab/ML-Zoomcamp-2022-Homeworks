# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Q1

# %%
np.__version__
# Out:
# '1.21.5'

# %% [markdown]
# # Q2

# %%
df = pd.read_csv('data.csv')
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# # Q3

# %%
df.groupby('Popularity').max()
# Out:
# /tmp/ipykernel_66036/946601801.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby('Popularity').max()
#                      Make                        Model  Year  Engine HP  \
# Popularity
# 2                  Spyker                           C8  2009      400.0
# 21                Genesis                          G80  2017      420.0
# 26             Oldsmobile                     Toronado  2004      275.0
# 61                Lincoln                       Zephyr  2017      380.0
# 67                Maybach                    Landaulet  2012      631.0
# 86            Rolls-Royce                       Wraith  2016      624.0
# 105                 Scion                           xD  2016      200.0
# 113            Alfa Romeo                           4C  2016      237.0
# ...

# %% [markdown]
# # Q4

# %%
AU = df[df['Make'].str.contains('Audi')]
AU
# Out:
#        Make Model  Year             Engine Fuel Type  Engine HP  \
# 17     Audi   100  1992             regular unleaded      172.0
# 18     Audi   100  1992             regular unleaded      172.0
# 19     Audi   100  1992             regular unleaded      172.0
# 20     Audi   100  1992             regular unleaded      172.0
# 21     Audi   100  1992             regular unleaded      172.0
# ...     ...   ...   ...                          ...        ...
# 10901  Audi   TTS  2016  premium unleaded (required)      292.0
# 10902  Audi   TTS  2017  premium unleaded (required)      292.0
# 11178  Audi    V8  1992             regular unleaded      276.0
# 11179  Audi    V8  1993             regular unleaded      276.0
# 11180  Audi    V8  1994             regular unleaded      276.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 17                  6.0            MANUAL  front wheel drive              4.0
# ...

# %%
AU.nunique() # my answer is the number in front of 'Model'
# Out:
# Make                   1
# Model                 34
# Year                  20
# Engine Fuel Type       5
# Engine HP             40
# Engine Cylinders       6
# Transmission Type      3
# Driven_Wheels          2
# Number of Doors        2
# Market Category       15
# Vehicle Size           3
# Vehicle Style          6
# highway MPG           23
# city mpg              18
# Popularity             1
# MSRP                 234
# dtype: int64

# %% [markdown]
# # Q5:

# %%
df.isnull().sum() #counted the columns with missing values
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# # Q6

# %%
df['Engine Cylinders'].median()
# Out:
# 6.0

# %%
m = df['Engine Cylinders'].mode()

# %%
df['Engine Cylinders'].fillna(m)
# Out:
# 0        6.0
# 1        6.0
# 2        6.0
# 3        6.0
# 4        6.0
#         ...
# 11909    6.0
# 11910    6.0
# 11911    6.0
# 11912    6.0
# 11913    6.0
# Name: Engine Cylinders, Length: 11914, dtype: float64

# %%
df['Engine Cylinders'].median()
# Out:
# 6.0

# %% [markdown]
# # Q7

# %%
lts = df[df['Make'].str.contains('Lotus')]
lts
# Out:
#        Make      Model  Year                Engine Fuel Type  Engine HP  \
# 3912  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3913  Lotus      Elise  2009     premium unleaded (required)      218.0
# 3914  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3915  Lotus      Elise  2010     premium unleaded (required)      189.0
# 3916  Lotus      Elise  2010     premium unleaded (required)      218.0
# 3917  Lotus      Elise  2011     premium unleaded (required)      189.0
# 3918  Lotus      Elise  2011     premium unleaded (required)      217.0
# 3919  Lotus      Elise  2011     premium unleaded (required)      217.0
# 4216  Lotus     Esprit  2002     premium unleaded (required)      350.0
# 4217  Lotus     Esprit  2003     premium unleaded (required)      350.0
# 4218  Lotus     Esprit  2004     premium unleaded (required)      350.0
# 4257  Lotus  Evora 400  2017     premium unleaded (required)      400.0
# ...

# %%
lts_1 = lts[['Engine HP', 'Engine Cylinders']]
lts_1
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3914      189.0               4.0
# 3915      189.0               4.0
# 3916      218.0               4.0
# 3917      189.0               4.0
# 3918      217.0               4.0
# 3919      217.0               4.0
# 4216      350.0               8.0
# 4217      350.0               8.0
# 4218      350.0               8.0
# 4257      400.0               6.0
# 4258      400.0               6.0
# 4259      276.0               6.0
# 4260      276.0               6.0
# 4261      276.0               6.0
# 4262      345.0               6.0
# 4263      345.0               6.0
# 4264      276.0               6.0
# 4265      345.0               6.0
# 4266      276.0               6.0
# 4267      345.0               6.0
# 4268      276.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0
# 4294      240.0               4.0
# ...

# %%
lts_2 = lts_1.drop_duplicates()
lts_2
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3918      217.0               4.0
# 4216      350.0               8.0
# 4257      400.0               6.0
# 4259      276.0               6.0
# 4262      345.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0

# %%
X = lts_2.values
X
# Out:
# array([[189.,   4.],
#        [218.,   4.],
#        [217.,   4.],
#        [350.,   8.],
#        [400.,   6.],
#        [276.,   6.],
#        [345.,   6.],
#        [257.,   4.],
#        [240.,   4.]])

# %%
XTX = np.dot(X.T,X)
XTX
# Out:
# array([[7.31684e+05, 1.34100e+04],
#        [1.34100e+04, 2.52000e+02]])

# %%
XTX = np.linalg.inv(XTX)
XTX
# Out:
# array([[ 5.53084235e-05, -2.94319825e-03],
#        [-2.94319825e-03,  1.60588447e-01]])

# %%
y = np.array([1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800])
y
# Out:
# array([1100,  800,  750,  850, 1300, 1000, 1000, 1300,  800])

# %%
XTX_X = np.dot(XTX,X.T)
XTX_X
# Out:
# array([[-1.31950096e-03,  2.84443321e-04,  2.29134897e-04,
#         -4.18763778e-03,  4.46417989e-03, -2.39406462e-03,
#          1.42221660e-03,  2.44147184e-03,  1.50122864e-03],
#        [ 8.60893170e-02,  7.36567735e-04,  3.67976598e-03,
#          2.54588185e-01, -2.13748621e-01,  1.51207962e-01,
#         -5.18727169e-02, -1.14048164e-01, -6.40137937e-02]])

# %%
w = np.dot(XTX_X,y)
w
# Out:
# array([  4.59494481, -63.56432501])
